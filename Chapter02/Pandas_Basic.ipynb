# %% [markdown]
# # Pandas Basic

# %% [markdown]
# ## Data Access
#
# Go to https://vaers.hhs.gov/data/datasets.html and Download 2021 **zip** Data. Please do not download only the CSV File.
#
# Drop it on the directory where this notebook is.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
vdata = pd.read_csv(
    "/home/sebastien/Documents/2021VAERSDATA.csv", encoding="iso-8859-1")
# Out:
# /tmp/ipykernel_43974/4125519052.py:1: DtypeWarning: Columns (7,12,15,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   vdata = pd.read_csv(

# %%
vdata.columns
# Out:
# Index(['VAERS_ID', 'RECVDATE', 'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX',
#        'RPT_DATE', 'SYMPTOM_TEXT', 'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT',
#        'HOSPITAL', 'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE',
#        'ONSET_DATE', 'NUMDAYS', 'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY',
#        'OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX', 'SPLTTYPE',
#        'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT',
#        'ALLERGIES'],
#       dtype='object')

# %%
vdata.dtypes
# Out:
# VAERS_ID          int64
# RECVDATE         object
# STATE            object
# AGE_YRS         float64
# CAGE_YR         float64
# CAGE_MO         float64
# SEX              object
# RPT_DATE         object
# SYMPTOM_TEXT     object
# DIED             object
# DATEDIED         object
# L_THREAT         object
# ER_VISIT         object
# HOSPITAL         object
# HOSPDAYS        float64
# X_STAY           object
# DISABLE          object
# RECOVD           object
# VAX_DATE         object
# ONSET_DATE       object
# NUMDAYS         float64
# LAB_DATA         object
# V_ADMINBY        object
# V_FUNDBY         object
# OTHER_MEDS       object
# CUR_ILL          object
# HISTORY          object
# PRIOR_VAX        object
# SPLTTYPE         object
# FORM_VERS         int64
# TODAYS_DATE      object
# BIRTH_DEFECT     object
# OFC_VISIT        object
# ER_ED_VISIT      object
# ALLERGIES        object
# dtype: object

# %%
vdata.shape
# Out:
# (753123, 35)

# %%
vdata.iloc[0]
# Out:
# VAERS_ID                                                   916600
# RECVDATE                                               01/01/2021
# STATE                                                          TX
# AGE_YRS                                                      33.0
# CAGE_YR                                                      33.0
# CAGE_MO                                                       NaN
# SEX                                                             F
# RPT_DATE                                                      NaN
# SYMPTOM_TEXT    Right side of epiglottis swelled up and hinder...
# DIED                                                          NaN
# DATEDIED                                                      NaN
# L_THREAT                                                      NaN
# ER_VISIT                                                      NaN
# HOSPITAL                                                      NaN
# HOSPDAYS                                                      NaN
# X_STAY                                                        NaN
# DISABLE                                                       NaN
# RECOVD                                                          Y
# VAX_DATE                                               12/28/2020
# ONSET_DATE                                             12/30/2020
# NUMDAYS                                                       2.0
# LAB_DATA                                                      NaN
# V_ADMINBY                                                     PVT
# V_FUNDBY                                                      NaN
# OTHER_MEDS                                                    NaN
# CUR_ILL                                                       NaN
# HISTORY                                                       NaN
# PRIOR_VAX                                                     NaN
# SPLTTYPE                                                      NaN
# FORM_VERS                                                       2
# TODAYS_DATE                                            01/01/2021
# BIRTH_DEFECT                                                  NaN
# OFC_VISIT                                                       Y
# ER_ED_VISIT                                                   NaN
# ALLERGIES                                       Pcn and bee venom
# Name: 0, dtype: object

# %%
vdata = vdata.set_index("VAERS_ID")
vdata
# Out:
#             RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# VAERS_ID
# 916600    01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 916601    01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 916602    01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 916603    01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 916604    01/01/2021    TX     47.0     47.0      NaN   F      NaN
# ...              ...   ...      ...      ...      ...  ..      ...
# 1997122   12/31/2021    NV     50.0     50.0      NaN   M      NaN
# 1998663   12/31/2021    TN     83.0     83.0      NaN   F      NaN
# 1998668   12/31/2021    SC      NaN      NaN      NaN   F      NaN
# 2554159   12/31/2021    CA     49.0      NaN      NaN   M      NaN
# 2594447   12/31/2021    PR     66.0     66.0      NaN   F      NaN
#
#                                                SYMPTOM_TEXT DIED    DATEDIED  \
# VAERS_ID
# 916600    Right side of epiglottis swelled up and hinder...  NaN         NaN
# 916601    Approximately 30 min post vaccination administ...  NaN         NaN
# 916602    About 15 minutes after receiving the vaccine, ...  NaN         NaN
# 916603    extreme fatigue, dizziness,. could not lift my...  NaN         NaN
# 916604    Injection site swelling, redness, warm to the ...  NaN         NaN
# ...                                                     ...  ...         ...
# 1997122   Hives all over the body and swelling of the li...  NaN         NaN
# 1998663   She had a stroke on April 1st, 2021 while at t...    Y  04/23/2021
# 1998668                                      Arm tenderness  NaN         NaN
# 2554159   He has been fully vaccinated with the Pfizer C...  NaN         NaN
# 2594447   DOSE ADMINISTERED AFTER BEING STORAGE FOR 30 D...  NaN         NaN
#
#           ...                                            CUR_ILL  \
# VAERS_ID  ...
# 916600    ...                                                NaN
# 916601    ...  Patient residing at nursing facility. See pati...
# 916602    ...                                                NaN
# 916603    ...                                   kidney infection
# 916604    ...                                                 Na
# ...       ...                                                ...
# 1997122   ...                                                NaN
# 1998663   ...  She had taken some shots for her back pain. Sh...
# 1998668   ...                                                NaN
# 2554159   ...                                                NaN
# 2594447   ...                                                NaN
#
#                                                     HISTORY  \
# VAERS_ID
# 916600                                                  NaN
# 916601    Patient residing at nursing facility. See pati...
# 916602                                                  NaN
# 916603    diverticulitis, mitral valve prolapse, osteoar...
# 916604                                                  NaN
# ...                                                     ...
# 1997122                                                 NaN
# 1998663   She had a stroke one week after taking the vac...
# 1998668                                                 NaN
# 2554159   Medical History/Concurrent Conditions: Diabete...
# 2594447                                                 NaN
#
#                                                   PRIOR_VAX  \
# VAERS_ID
# 916600                                                  NaN
# 916601                                                  NaN
# 916602                                                  NaN
# 916603    got measles from measel shot, mums from mumps ...
# 916604                                                  NaN
# ...                                                     ...
# 1997122                                                 NaN
# 1998663                                                 NaN
# 1998668                                                 NaN
# 2554159                                                 NaN
# 2594447                                                 NaN
#
#                           SPLTTYPE FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# VAERS_ID
# 916600                         NaN         2  01/01/2021          NaN
# 916601                         NaN         2  01/01/2021          NaN
# 916602                         NaN         2  01/01/2021          NaN
# 916603                         NaN         2  01/01/2021          NaN
# 916604                         NaN         2  01/01/2021          NaN
# ...                            ...       ...         ...          ...
# 1997122                        NaN         2  12/31/2021          NaN
# 1998663                        NaN         2         NaN            Y
# 1998668                        NaN         2  12/31/2021          NaN
# 2554159   USPFIZER INC202101798458         2  12/28/2021          NaN
# 2594447                        NaN         2  12/30/2021          NaN
#
#          OFC_VISIT ER_ED_VISIT  \
# VAERS_ID
# 916600           Y         NaN
# 916601           Y         NaN
# 916602         NaN           Y
# 916603         NaN         NaN
# 916604         NaN         NaN
# ...            ...         ...
# 1997122        NaN         NaN
# 1998663          Y           Y
# 1998668        NaN         NaN
# 2554159        NaN         NaN
# 2594447        NaN         NaN
#
#                                                   ALLERGIES
# VAERS_ID
# 916600                                    Pcn and bee venom
# 916601                                              "Dairy"
# 916602                                            Shellfish
# 916603    Diclofenac, novacaine, lidocaine, pickles, tom...
# 916604                                                   Na
# ...                                                     ...
# 1997122                                                 NaN
# 1998663   Allergic to iodine, penicillian and codene, su...
# 1998668                                                 NaN
# 2554159                                                 NaN
# 2594447                                                 NaN
#
# [753123 rows x 34 columns]

# %%
vdata.loc[916600]
# Out:
# RECVDATE                                               01/01/2021
# STATE                                                          TX
# AGE_YRS                                                      33.0
# CAGE_YR                                                      33.0
# CAGE_MO                                                       NaN
# SEX                                                             F
# RPT_DATE                                                      NaN
# SYMPTOM_TEXT    Right side of epiglottis swelled up and hinder...
# DIED                                                          NaN
# DATEDIED                                                      NaN
# L_THREAT                                                      NaN
# ER_VISIT                                                      NaN
# HOSPITAL                                                      NaN
# HOSPDAYS                                                      NaN
# X_STAY                                                        NaN
# DISABLE                                                       NaN
# RECOVD                                                          Y
# VAX_DATE                                               12/28/2020
# ONSET_DATE                                             12/30/2020
# NUMDAYS                                                       2.0
# LAB_DATA                                                      NaN
# V_ADMINBY                                                     PVT
# V_FUNDBY                                                      NaN
# OTHER_MEDS                                                    NaN
# CUR_ILL                                                       NaN
# HISTORY                                                       NaN
# PRIOR_VAX                                                     NaN
# SPLTTYPE                                                      NaN
# FORM_VERS                                                       2
# TODAYS_DATE                                            01/01/2021
# BIRTH_DEFECT                                                  NaN
# OFC_VISIT                                                       Y
# ER_ED_VISIT                                                   NaN
# ALLERGIES                                       Pcn and bee venom
# Name: 916600, dtype: object

# %%
vdata.head(3)
# Out:
#             RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# VAERS_ID
# 916600    01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 916601    01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 916602    01/01/2021    WA     23.0     23.0      NaN   F      NaN
#
#                                                SYMPTOM_TEXT DIED DATEDIED  \
# VAERS_ID
# 916600    Right side of epiglottis swelled up and hinder...  NaN      NaN
# 916601    Approximately 30 min post vaccination administ...  NaN      NaN
# 916602    About 15 minutes after receiving the vaccine, ...  NaN      NaN
#
#           ...                                            CUR_ILL  \
# VAERS_ID  ...
# 916600    ...                                                NaN
# 916601    ...  Patient residing at nursing facility. See pati...
# 916602    ...                                                NaN
#
#                                                     HISTORY PRIOR_VAX  \
# VAERS_ID
# 916600                                                  NaN       NaN
# 916601    Patient residing at nursing facility. See pati...       NaN
# 916602                                                  NaN       NaN
#
#           SPLTTYPE FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# VAERS_ID
# 916600         NaN         2  01/01/2021          NaN         Y         NaN
# 916601         NaN         2  01/01/2021          NaN         Y         NaN
# 916602         NaN         2  01/01/2021          NaN       NaN           Y
#
#                   ALLERGIES
# VAERS_ID
# 916600    Pcn and bee venom
# 916601              "Dairy"
# 916602            Shellfish
#
# [3 rows x 34 columns]

# %%
vdata["AGE_YRS"].max()
# Out:
# 119.0

# %%
vdata["AGE_YRS"].sort_values().plot(use_index=False)
# Out:
# <Axes: >

# %%
vdata["AGE_YRS"].sort_values().plot(use_index=False)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1, 2, sharey=True, dpi=300)
fig.suptitle("Age of adverse events")
vdata["AGE_YRS"].sort_values().plot(
    use_index=False, ax=ax[0],
    xlabel="Obervation", ylabel="Age")
vdata["AGE_YRS"].plot.hist(bins=20, orientation="horizontal")
fig.savefig("adverse.png")

# %%
vdata["AGE_YRS"].dropna().apply(lambda x: int(x)).value_counts()
# not documented
# Out:
# AGE_YRS
# 50     12573
# 65     12414
# 60     12241
# 51     12102
# 59     11957
#        ...
# 115        6
# 119        4
# 106        2
# 113        1
# 109        1
# Name: count, Length: 111, dtype: int64

# %%
vdata.DIED.value_counts(dropna=False)
# Out:
# DIED
# NaN    742568
# Y       10555
# Name: count, dtype: int64

# %%
vdata["is_dead"] = (vdata.DIED == "Y")
vdata.head()
# Out:
#             RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# VAERS_ID
# 916600    01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 916601    01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 916602    01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 916603    01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 916604    01/01/2021    TX     47.0     47.0      NaN   F      NaN
#
#                                                SYMPTOM_TEXT DIED DATEDIED  \
# VAERS_ID
# 916600    Right side of epiglottis swelled up and hinder...  NaN      NaN
# 916601    Approximately 30 min post vaccination administ...  NaN      NaN
# 916602    About 15 minutes after receiving the vaccine, ...  NaN      NaN
# 916603    extreme fatigue, dizziness,. could not lift my...  NaN      NaN
# 916604    Injection site swelling, redness, warm to the ...  NaN      NaN
#
#           ...                                            HISTORY  \
# VAERS_ID  ...
# 916600    ...                                                NaN
# 916601    ...  Patient residing at nursing facility. See pati...
# 916602    ...                                                NaN
# 916603    ...  diverticulitis, mitral valve prolapse, osteoar...
# 916604    ...                                                NaN
#
#                                                   PRIOR_VAX SPLTTYPE  \
# VAERS_ID
# 916600                                                  NaN      NaN
# 916601                                                  NaN      NaN
# 916602                                                  NaN      NaN
# 916603    got measles from measel shot, mums from mumps ...      NaN
# 916604                                                  NaN      NaN
#
#           FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# VAERS_ID
# 916600            2  01/01/2021          NaN         Y         NaN
# 916601            2  01/01/2021          NaN         Y         NaN
# 916602            2  01/01/2021          NaN       NaN           Y
# 916603            2  01/01/2021          NaN       NaN         NaN
# 916604            2  01/01/2021          NaN       NaN         NaN
#
#                                                   ALLERGIES  is_dead
# VAERS_ID
# 916600                                    Pcn and bee venom    False
# 916601                                              "Dairy"    False
# 916602                                            Shellfish    False
# 916603    Diclofenac, novacaine, lidocaine, pickles, tom...    False
# 916604                                                   Na    False
#
# [5 rows x 35 columns]

# %%
dead = vdata[vdata.is_dead]
vax = pd.read_csv("/home/sebastien/Documents/2021VAERSVAX.csv", encoding="iso-8859-1").set_index("VAERS_ID")
print(vax.columns)
print(vax.shape)
print(vax.VAX_TYPE.unique())
# Out:
# Index(['VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_DOSE_SERIES', 'VAX_ROUTE',
#        'VAX_SITE', 'VAX_NAME'],
#       dtype='object')
# (797369, 7)
# ['COVID19' 'FLUC4' 'DTAPHEPBIP' 'HIBV' 'PNC13' 'RV1' 'UNK' 'FLU4' 'PPV'
#  'FLUA3' 'VARZOS' 'MMR' 'DT' 'HPV9' 'DTAP' 'MMRV' 'TDAP' 'FLUR4'
#  'DTAPIPVHIB' 'HEPA' 'MNQ' 'FLUX' 'YF' 'ANTH' 'HEP' 'VARCEL' 'RV5' 'HPV4'
#  'MENB' 'IPV' 'RAB' 'FLUA4' 'FLUN4' 'DTAPIPV' 'TYP' 'ADEN_4_7' 'CHOL'
#  'TTOX' 'FLU3' 'FLUC3' 'HEPAB' 'TD' 'EBZR' 'PNC' 'DF' 'HPVX' 'FLUX(H1N1)'
#  'RVX' 'DTP' 'MEN' 'JEV1' 'BCG' 'PER' 'SMALL' 'OPV' 'TDAPIPV' 'FLUN3'
#  'FLU(H1N1)' '6VAX-F' 'MNQHIB' 'DTPHEP' 'JEVX' 'DTPPVHBHPB' 'FLUR3' 'DTOX'
#  'MU' 'HEPATYP' 'PNC10' 'H5N1' 'COVID19-2']

# %%
vax.groupby("VAX_TYPE").size().sort_values()
# Out:
# VAX_TYPE
# HEPATYP         1
# H5N1            1
# TDAPIPV         1
# MNQHIB          1
# MU              1
#             ...
# HPV9         1826
# FLU4         5431
# UNK          9628
# VARZOS      14351
# COVID19    742228
# Length: 70, dtype: int64

# %%
vax19 = vax[vax.VAX_TYPE == "COVID19"]
vax19_dead = dead.join(vax19)
# join on id, discuss
vax19_dead.index.value_counts()
# Out:
# VAERS_ID
# 1215401    10
# 1971984     8
# 1775761     3
# 1909908     3
# 1741085     3
#            ..
# 1241672     1
# 1241805     1
# 1241873     1
# 1241936     1
# 2675414     1
# Name: count, Length: 10555, dtype: int64

# %%
baddies = vax19_dead.groupby("VAX_LOT").size().sort_values(ascending=False)
for i, (lot, cnt) in enumerate(baddies.items()):
    print(lot, cnt, len(vax19_dead[vax19_dead.VAX_LOT == lot].groupby("STATE")))
    if i == 10:
        break
# Out:
# Unknown 224 32
# EN6201 157 32
# unknown 127 21
# EN6200 120 22
# EN5318 120 29
# EN6198 114 24
# EL9261 111 22
# EL3248 102 18
# EM9810 101 21
# EN6202 98 19
# 039K20A 97 13
